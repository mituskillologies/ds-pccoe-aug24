# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.array([2,14,17,34,38,56,67,78,81,93])
y = np.array([14,15,11,18,34,41,48,59,67,71])

# %%
# scatter plot
plt.scatter(x, y)

# %%
plt.plot(x, y)

# %%
df = pd.read_csv('student.csv')

# %%
plt.bar(df['name'], df['marks'])
# Out:
# <BarContainer object of 10 artists>

# %%
langs = ['C','C++','Java','Python','PHP','R']
studs = [56,89,90,189,123,42]

# %%
plt.pie(studs, labels=langs, autopct='%2.2f%%');

# %%
df['age'].value_counts()
# Out:
# age
# 20    4
# 21    2
# 19    2
# 22    1
# 23    1
# Name: count, dtype: int64

# %%
plt.pie(df['age'].value_counts(), labels=df['age'].value_counts().index,
       autopct='%2.2f%%');

# %%
marks = [67,45,47,69,86,47,55,61,63,69,77,75,49,21,37,66,78]

# %%
plt.hist(marks, bins=range(0,100,10));
plt.xticks(range(0,100,10));
